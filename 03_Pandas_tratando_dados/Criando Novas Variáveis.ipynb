# %% [markdown]
# # Relatório de Análises VI

# %% [markdown]
# ## Criando novas variáveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('data/aluguel_residencial.csv', sep=';')

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2
# 0       390.0   20.0     53.33
# 1       230.0    0.0     16.67
# ...

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2  Valor Bruto
# 0       390.0   20.0     53.33       1210.0
# ...

# %% [markdown]
# ## Criando a coluna Valor M2

# %%
# dados['Valor m2'] = dados['Valor'] / dados['Area']

# %% [markdown]
# ### Formatando os valores para mostrar somente duas casas decimais

# %%
# dados['Valor m2'] = dados['Valor m2'].round(2)

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Area']).round(2)

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2  Valor Bruto  Valor Bruto m2
# ...

# %% [markdown]
# ## Criando a coluna Tipo Agregado

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')
# apply -> permite que apliquemos uma funcao a cada registro do DataFrame

# %%
dados
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %% [markdown]
# ## Excluindo variáveis

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto', 'Valor Bruto m2']])

# %%
dados_aux.head(10)
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto  Valor Bruto m2
# 0   Apartamento     53.33       1210.0           80.67
# 1   Apartamento     16.67       1030.0           21.46
# 2   Apartamento     26.00       1618.0           32.36
# 3   Apartamento     21.43       2216.0           31.66
# 4   Apartamento     16.67       1969.0           21.88
# 5   Apartamento     50.00       2611.0           65.28
# 6   Apartamento     17.59       1278.0           23.67
# 7   Apartamento     25.37       2436.0           36.36
# 8   Apartamento     17.27       2738.0           24.89
# 9   Apartamento     14.71       1670.0           24.56

# %% [markdown]
# ### Primeira forma

# %%
del dados_aux['Valor Bruto']

# %%
dados_aux.head(10)
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto m2
# 0   Apartamento     53.33           80.67
# 1   Apartamento     16.67           21.46
# 2   Apartamento     26.00           32.36
# 3   Apartamento     21.43           31.66
# 4   Apartamento     16.67           21.88
# 5   Apartamento     50.00           65.28
# 6   Apartamento     17.59           23.67
# 7   Apartamento     25.37           36.36
# 8   Apartamento     17.27           24.89
# 9   Apartamento     14.71           24.56

# %% [markdown]
# ### Segunda forma

# %%
dados_aux.pop('Valor Bruto m2')
# Out:
# 0        80.67
# 1        21.46
# 2        32.36
# 3        31.66
# 4        21.88
#          ...
# 19826    51.70
# 19827    65.43
# 19828    59.29
# 19829    90.27
# 19830    43.52
# Name: Valor Bruto m2, Length: 19831, dtype: float64

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2
# 0       Apartamento     53.33
# 1       Apartamento     16.67
# 2       Apartamento     26.00
# 3       Apartamento     21.43
# 4       Apartamento     16.67
# ...             ...       ...
# 19826   Apartamento     40.00
# 19827   Apartamento     39.13
# 19828   Apartamento     45.83
# 19829   Apartamento     68.18
# 19830   Apartamento     29.63
#
# [19831 rows x 2 columns]

# %% [markdown]
# ### Terceira Forma

# %%
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis=1, inplace=True)
# axis = 1 -> Coluna
# axis = 0 -> Linha

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
dados.to_csv('data/aluguel_residencial.csv', sep=';', index=False)
